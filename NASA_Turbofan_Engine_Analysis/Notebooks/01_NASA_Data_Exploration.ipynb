# %% [markdown]
# # NASA Turbofan Engine Sensor Analysis
# # Part 1: Data Exploration
#
# Author:Jessica Oladapo-Fadeni
# Date: August 2026
# Objective:
# Explore and understand the NASA C-MAPSS FD001 before beginning engineering analysis.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.use("default")

# %%
column_names=(["engine_id","cycle"]+[f"setting_{i}" for i in range(1,4)]+[f"sensor_{i}" for i in range (1,22)])

df=pd.read_csv("../data/raw/train_FD001.txt",sep=r"\s+",header=None)



df.columns=column_names

# %%
df.head()
# Out:
#    engine_id  cycle  setting_1  setting_2  setting_3  sensor_1  sensor_2  \
# 0          1      1    -0.0007    -0.0004      100.0    518.67    641.82
# 1          1      2     0.0019    -0.0003      100.0    518.67    642.15
# 2          1      3    -0.0043     0.0003      100.0    518.67    642.35
# 3          1      4     0.0007     0.0000      100.0    518.67    642.35
# 4          1      5    -0.0019    -0.0002      100.0    518.67    642.37
#
#    sensor_3  sensor_4  sensor_5  ...  sensor_12  sensor_13  sensor_14  \
# 0   1589.70   1400.60     14.62  ...     521.66    2388.02    8138.62
# 1   1591.82   1403.14     14.62  ...     522.28    2388.07    8131.49
# 2   1587.99   1404.20     14.62  ...     522.42    2388.03    8133.23
# 3   1582.79   1401.87     14.62  ...     522.86    2388.08    8133.83
# 4   1582.85   1406.22     14.62  ...     522.19    2388.04    8133.80
#
#    sensor_15  sensor_16  sensor_17  sensor_18  sensor_19  sensor_20  sensor_21
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20631 entries, 0 to 20630
# Data columns (total 26 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   engine_id  20631 non-null  int64
#  1   cycle      20631 non-null  int64
#  2   setting_1  20631 non-null  float64
#  3   setting_2  20631 non-null  float64
#  4   setting_3  20631 non-null  float64
#  5   sensor_1   20631 non-null  float64
#  6   sensor_2   20631 non-null  float64
#  7   sensor_3   20631 non-null  float64
#  8   sensor_4   20631 non-null  float64
#  9   sensor_5   20631 non-null  float64
#  10  sensor_6   20631 non-null  float64
#  11  sensor_7   20631 non-null  float64
#  12  sensor_8   20631 non-null  float64
#  13  sensor_9   20631 non-null  float64
#  14  sensor_10  20631 non-null  float64
#  15  sensor_11  20631 non-null  float64
#  16  sensor_12  20631 non-null  float64
#  17  sensor_13  20631 non-null  float64
#  18  sensor_14  20631 non-null  float64
# ...

# %%
df.describe()
# Out:
#           engine_id         cycle     setting_1     setting_2  setting_3  \
# count  20631.000000  20631.000000  20631.000000  20631.000000    20631.0
# mean      51.506568    108.807862     -0.000009      0.000002      100.0
# std       29.227633     68.880990      0.002187      0.000293        0.0
# min        1.000000      1.000000     -0.008700     -0.000600      100.0
# 25%       26.000000     52.000000     -0.001500     -0.000200      100.0
# 50%       52.000000    104.000000      0.000000      0.000000      100.0
# 75%       77.000000    156.000000      0.001500      0.000300      100.0
# max      100.000000    362.000000      0.008700      0.000600      100.0
#
#        sensor_1      sensor_2      sensor_3      sensor_4      sensor_5  ...  \
# count  20631.00  20631.000000  20631.000000  20631.000000  2.063100e+04  ...
# mean     518.67    642.680934   1590.523119   1408.933782  1.462000e+01  ...
# std        0.00      0.500053      6.131150      9.000605  5.329200e-15  ...
# ...

# %% [markdown]
# ## Initial Observations
#
# How many rows?
# 20631
# How many columns?
# 26
# How many unique engines?
# 100
# How many sensors?
# 21
# How many operating settings?
# 3
# Are there missing values?
# no
# Why does Engine 1 appear 20 times?
# This is done because the engine is tested throughout the duration of its life cycle.
#
# How many cycles did each engine complete throughout its lifetime?

# %%
df.isnull().sum()
# Out:
# engine_id    0
# cycle        0
# setting_1    0
# setting_2    0
# setting_3    0
# sensor_1     0
# sensor_2     0
# sensor_3     0
# sensor_4     0
# sensor_5     0
# sensor_6     0
# sensor_7     0
# sensor_8     0
# sensor_9     0
# sensor_10    0
# sensor_11    0
# sensor_12    0
# sensor_13    0
# sensor_14    0
# sensor_15    0
# sensor_16    0
# sensor_17    0
# sensor_18    0
# sensor_19    0
# sensor_20    0
# sensor_21    0
# dtype: int64

# %%
df.shape
# Out:
# (20631, 26)

# %%
df["engine_id"].nunique()
# Out:
# 100

# %%
df.head(20)
# Out:
#     engine_id  cycle  setting_1  setting_2  setting_3  sensor_1  sensor_2  \
# 0           1      1    -0.0007    -0.0004      100.0    518.67    641.82
# 1           1      2     0.0019    -0.0003      100.0    518.67    642.15
# 2           1      3    -0.0043     0.0003      100.0    518.67    642.35
# 3           1      4     0.0007     0.0000      100.0    518.67    642.35
# 4           1      5    -0.0019    -0.0002      100.0    518.67    642.37
# 5           1      6    -0.0043    -0.0001      100.0    518.67    642.10
# 6           1      7     0.0010     0.0001      100.0    518.67    642.48
# 7           1      8    -0.0034     0.0003      100.0    518.67    642.56
# 8           1      9     0.0008     0.0001      100.0    518.67    642.12
# 9           1     10    -0.0033     0.0001      100.0    518.67    641.71
# 10          1     11     0.0018    -0.0003      100.0    518.67    642.28
# 11          1     12     0.0016     0.0002      100.0    518.67    642.06
# ...

# %%
engine_life= df.groupby("engine_id")["cycle"].max()

engine_life.head()
# Out:
# engine_id
# 1    192
# 2    287
# 3    179
# 4    189
# 5    269
# Name: cycle, dtype: int64

# %%
engine_life.describe()
# Out:
# count    100.000000
# mean     206.310000
# std       46.342749
# min      128.000000
# 25%      177.000000
# 50%      199.000000
# 75%      229.250000
# max      362.000000
# Name: cycle, dtype: float64
